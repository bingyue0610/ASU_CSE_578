# %%
本次作业针对数据进行操作并形成以下内容: 
1. 做出各年参与这所属国家饼图,并以2004年和2014年为例说明。
2. 定义比赛激烈程度指数（比赛比分约接近，局数越多则越激烈），制作历年激烈程度竞赛图。
3. 制作参与选手行为矩阵，根据相似性做Treemap.

# %%
以下为2004参赛选手量图，可以点击右侧国家按钮查看变化。
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
以下为2014参赛选手量图，可以点击右侧国家按钮查看变化。对比来看，FRA，ESP，USA选手量常居首位。
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
下图为历年比赛激烈程度，基本可以发现决胜与半决赛的激烈程度通常为为最高。
# Out:
# <video width="904" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
以下为比赛选手相似程度的Treemap，可以选框放大或缩小查看细节。
# Out:
# <div>                            <div id="7bd7fd04-3e17-478d-9a58-7c149ece967f" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bd7fd04-3e17-478d-9a58-7c149ece967f")) {                    Plotly.newPlot(                        "7bd7fd04-3e17-478d-9a58-7c149ece967f",                        [{"hoverinfo": "text", "marker": {"color": "rgb(61,153,112)"}, "mode": "lines", "type": "scatter", "x": [25.0, 25.0, 35.0, 35.0], "xaxis": "x", "y": [0.0, 23.964365211705484, 23.964365211705484, 0.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(61,153,112)"}, "mode": "lines", "type": "scatter", "x": [45.0, 45.0, 55.0, 55.0], "xaxis": "x", "y": [0.0, 25.22632157093063, 25.22632157093063, 0.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"colo
# ...
